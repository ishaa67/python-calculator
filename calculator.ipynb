# %%
while True:
    print("\n1.Addition \n2.Subtraction \n3.Multiplication \n4.Division \n5.Modulus")
    
    ch=int(input("Enter your choise(1 to 5):"))
     
    num1=int(input("Enter number1:"))
    num2=int(input("enter number2:"))
    
    
    if ch==1:
        print("Addition",num1+num2)
    elif ch==2:
        print("Subtraction",num1-num2)
    elif ch==3:
        print("Multiplication",num1*num2)
    elif ch==4:
        print("Division",num1/num2)
    elif ch==5:
        print("Modulus",num1%num2)
    
    else:
     print("Invalid")
# Out:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Modulus
# Enter your choise(1 to 5): 5
# Enter number1: 23
# enter number2: 3
# Modulus 2
#
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Modulus
